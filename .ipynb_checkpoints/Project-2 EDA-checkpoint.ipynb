# %% [markdown]
# <h1 style="font-size:3em;  font-family:roboto, sans-serif; color:orange; font-weight:700">Objective</h1>
# <ul style="font-size:1em; font-weight:400; color:blue">
#     <li>Import Libraries</li>
#     <li>Import Dataset</li>
#     <li>Understanding Dataset</li>
#     <li>Data Prep</li>
#     <li>EDA</li>
# </ul>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("/
